# %%
import selenium
from selenium import webdriver as wb
webD=wb.Chrome('chromedriver.exe')
webD.get('https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa,Residential-Plot&cityName=Bangalore')

# %%
def getURL(string):
    from urlextract import URLExtract
    extractor = URLExtract()
    urls = extractor.find_urls(string)
    x1=str(urls[0]).find(',')
    return str(urls[0])[:x1-1]

# %%
propertyList=webD.find_elements_by_class_name('m-srp-card')
urls=[]
for i in propertyList:
    urls.append(getURL(i.get_attribute('data-code')))

# %%
len(urls)
# Out:
# 780

# %%
"""Headline=webD.find_element_by_xpath('//*[@id="propertyDetailTabId"]/div[3]/div[1]/div/div[1]/div[3]/h1/span[1]').text
Price=webD.find_element_by_xpath('//*[@id="priceSv"]').text
Address=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[4]/div[2]').text
Bedrooms=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[1]/div[2]/div').text



try:
    Bathrooms=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[2]/div[2]')
except:
    Bathrooms="NaN"
try:
    Balcony=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[3]/div[2]')
except:
    Balcony="NaN"
try:
    SuperArea=webD.find_element_by_xpath('//*[@id="secondFoldDisplay"]/div[1]/div[2]')
except:
    SuperArea="NaN"
Status=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[1]/div[2]').text
TransactionType=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[2]/div[2]').text
try:
    Floor=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[3]/div[2]')
except:
    Floor="Nan"
Carparking=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[1]/div[2]')
try:
    Furnishedstatus=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[4]/div[2]')
except:
    Furnishedstatus="NaN"
    
Lifts=webD.find_element_by_xpath('//*[@id="detailsHighLight-id"]/ul/li[3]').text
try:
    Description=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[1]')
except:
    Description="NaN"
Pricebreakup=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[2]/div[2]').text
try:
    Landmarks=webD.find_element_by_xpath('//*[@id="detailsHighLight-id"]/ul')
except:
    Landmarks="NaN"



Ageofconstruction="NaN"
Pricecomparison="NaN"
Expectedrent="NaN"
MonthlyEMI="NaN"


OwnerBuilder=webD.find_element_by_xpath('//*[@id="thirdFoldDisplay"]/div[1]/div[2]/span/a')
TypeofOwnership=webD.find_element_by_xpath('//*[@id="thirdFoldDisplay"]/div[2]/div[2]')"""
# Out:
# 'Headline=webD.find_element_by_xpath(\'//*[@id="propertyDetailTabId"]/div[3]/div[1]/div/div[1]/div[3]/h1/span[1]\').text\nPrice=webD.find_element_by_xpath(\'//*[@id="priceSv"]\').text\nAddress=webD.find_element_by_xpath(\'//*[@id="propDetailDescriptionId"]/div[2]/div/div[4]/div[2]\').text\nBedrooms=webD.find_element_by_xpath(\'//*[@id="firstFoldDisplay"]/div[1]/div[2]/div\').text\n\n\n\ntry:\n    Bathrooms=webD.find_element_by_xpath(\'//*[@id="firstFoldDisplay"]/div[2]/div[2]\')\nexcept:\n    Bathrooms="NaN"\ntry:\n    Balcony=webD.find_element_by_xpath(\'//*[@id="firstFoldDisplay"]/div[3]/div[2]\')\nexcept:\n    Balcony="NaN"\ntry:\n    SuperArea=webD.find_element_by_xpath(\'//*[@id="secondFoldDisplay"]/div[1]/div[2]\')\nexcept:\n    SuperArea="NaN"\nStatus=webD.find_element_by_xpath(\'//*[@id="fourthFoldDisplay"]/div[1]/div[2]\').text\nTransactionType=webD.find_element_by_xpath(\'//*[@id="fourthFoldDisplay"]/div[2]/div[2]\').text\ntry:\n    Floor=webD.find_element_by_xpath(\'//*[@id="fourthFoldDisplay"]/div[3]/div[2]\')\nexcept:\n    Floor="Nan"\nCarparking=webD.find_element_by_xpath(\'//*[@id="fourthFoldDisplay"]/div[1]/div[2]\')\ntry:\n    Furnishedstatus=webD.find_element_by_xpath(\'//*[@id="fourthFoldDisplay"]/div[4]/div[2]\')\nexcept:\n    Furnishedstatus="NaN"\n    \nLifts=webD.find_element_by_xpath(\'//*[@id="detailsHighLight-id"]/ul/li[3]\').text\ntry:\n    Description=webD.find_element_by_xpath(\'//*[@id="propDetailDescriptionId"]/div[2]/div/div[1]\')\nexcept:\n    Description="NaN"\nPricebreakup=webD.find_element_by_xpath(\'//*[@id="propDetailDescriptionId"]/div[2]/div/div[2]/div[2]\').text\ntry:\n    Landmarks=webD.find_element_by_xpath(\'//*[@id="detailsHighLight-id"]/ul\')\nexcept:\n    Landmarks="NaN"\n\n\n\nAgeofconstruction="NaN"\nPricecomparison="NaN"\nExpectedrent="NaN"\nMonthlyEMI="NaN"\n\n\nOwnerBuilder=webD.find_element_by_xpath(\'//*[@id="thirdFoldDisplay"]/div[1]/div[2]/span/a\')\nTypeofOwnership=webD.find_element_by_xpath(\'//*[@id="thirdFoldDisplay"]/div[2]/div[2]\')'

# %%
from tqdm import tqdm
allDetails=[]
for i in tqdm(urls):
    #webD=wb.Chrome('chromedriver.exe')
    webD.get(i)
    
    
    
    
    
    try:
        Headline=webD.find_element_by_xpath('//*[@id="propertyDetailTabId"]/div[3]/div[1]/div/div[1]/div[3]/h1/span[1]').text
    except:
        Headline="NaN"
    
    try:
        Price=webD.find_element_by_xpath('//*[@id="priceSv"]').text
    except:
        Price="NaN"
    
    try:
        Address=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[4]/div[2]').text
    except:
        Address="NaN"

    try:
        Bedrooms=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[1]/div[2]/div').text
    except:
        Bedrooms="NaN"

    try:
        Lift=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[8]/div[2]/div/div[1]').text
    except:
        Lift="Nan"

    try:
        Bathrooms=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[2]/div[2]').text
    except:
        Bathrooms="NaN"
    try:
        Balcony=webD.find_element_by_xpath('//*[@id="firstFoldDisplay"]/div[3]/div[2]').text
    except:
        Balcony="NaN"
    try:
        SuperArea=webD.find_element_by_xpath('//*[@id="secondFoldDisplay"]/div[1]/div[2]').text
    except:
        SuperArea="NaN"
        
    try:
        Status=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[1]/div[2]').text
    except:
        Status="NaN"
    
    try:
        TransactionType=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[2]/div[2]').text
    except:
        TransactionType="NaN"
    
    
    
    
    try:
        Floor=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[3]/div[2]').text
    except:
        Floor="Nan"
    try:
        Carparking=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[1]/div[2]').text
    except:
        Carparking="NaN"
    try:
        Furnishedstatus=webD.find_element_by_xpath('//*[@id="fourthFoldDisplay"]/div[4]/div[2]').text
    except:
        Furnishedstatus="NaN"

    try:
        Description=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[1]').text
    except:
        Description="NaN"
        
        
    try:
        Pricebreakup=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[2]/div[2]').text
    except:
        Pricebreakup="NaN"
    try:
        Landmarks=webD.find_element_by_xpath('//*[@id="propDetailDescriptionId"]/div[2]/div/div[6]/div[2]').text
    except:
        Landmarks="NaN"



    Ageofconstruction="NaN"
    Pricecomparison="NaN"
    Expectedrent="NaN"
    MonthlyEMI="NaN"

    try:
        OwnerBuilder=webD.find_element_by_xpath('//*[@id="thirdFoldDisplay"]/div[1]/div[2]/span/a').text
    except:
        OwnerBuilder="Nan"
    try:
        TypeofOwnership=webD.find_element_by_xpath('//*[@id="thirdFoldDisplay"]/div[2]/div[2]').text
    except:
        TypeofOwnership="NaN"
    try:
        Pricepersqft=webD.find_element_by_xpath('//*[@id="secondFoldDisplay"]/div[1]/div[3]').text
    except:
        Pricepersqft="NaN"
    
    
    
    
    
    
    
    data={
    'Headline':Headline,
    'Price':Price,
    'Address':Address,
    'Bedrooms':Bedrooms,
    'Bathrooms':Bathrooms,
    'Balcony':Balcony,
    'Super Area':SuperArea,
    'Price per sqft':Pricepersqft,
    'Status':Status,
    'Transaction Type':TransactionType,
    'Floor':Floor,
    'Car parking':Carparking,
    'Furnished status':Furnishedstatus,
    'Lifts':Lift,
    'Description':Description,
    'Price breakup':Pricebreakup,
    'Landmarks':Landmarks,
    'Age of construction':Ageofconstruction,
    'Price comparison':Pricecomparison,
    'Expected rent':Expectedrent,
    'Monthly EMI':MonthlyEMI,
    'Owner/Builder':OwnerBuilder,
    'Type of Ownership':TypeofOwnership
    }
    allDetails.append(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 780/780 [36:56<00:00,  2.84s/it]

# %% [markdown]
# # data csv formatting

# %%
import pandas as pd

# %%
df=pd.DataFrame(allDetails)

# %%
df.to_csv('OutPut.csv')

# %%
df
# Out:
#                                               Headline       Price  \
# 0    1200 Sq-ft Residential Plot/Land for Sale in C...  ₹ 19.2 Lac
# 1                                 2 BHK 830 Sq-ft Flat  ₹ 45.0 Lac
# 2                                3 BHK 1809 Sq-ft Flat   ₹ 1.54 Cr
# 3                                3 BHK 1556 Sq-ft Flat   ₹ 1.06 Cr
# 4                                3 BHK 1330 Sq-ft Flat  ₹ 46.5 Lac
# ..                                                 ...         ...
# 775                              3 BHK 1455 Sq-ft Flat  ₹ 89.0 Lac
# 776  530 Sq-ft Commercial Office Space for Sale in ...   ₹ 2.40 Cr
# 777                                         2 BHK Flat  ₹ 95.0 Lac
# 778                                    4 BHK Penthouse   ₹ 2.75 Cr
# 779                                        4 BHK Villa   ₹ 1.60 Cr
#
#                                                Address          Bedrooms  \
# 0                 Jigani, Bangalore - South, Karnataka              sqft
# 1                 Kengeri, Bangalore - West, Karnataka   2 See Dimension
# 2        Kadubeesanahalli, Bangalore - East, Karnataka                 3
# 3      Thambuchetty Palya, Bangalore - East, Karnataka                 3
# 4    Electronic City Phase 2, Bangalore - South, Ka...   3 See Dimension
# ..                                                 ...               ...
# 775  Power Back Up, Lift, Rain Water Harvesting, Cl...                 3
# 776    Bannerghatta Road, Bangalore - South, Karnataka                 1
# 777                               Bangalore, Karnataka                 2
# 778                             Lift, Reserved Parking                 4
# 779                 Power Back Up, Park, Water Storage  4 See Dimensions
#
#     Bathrooms Balcony Super Area Price per sqft              Status  \
# 0         NaN     NaN        NaN            NaN   1 Covered, 1 Open
# 1           2     NaN   830 sqft   ₹ 5,422/sqft  Under Construction
# 2           3     NaN  1809 sqft   ₹ 8,513/sqft       Ready to Move
# 3           3     NaN  1556 sqft   ₹ 6,812/sqft  Under Construction
# 4           2       1  1330 sqft   ₹ 3,496/sqft  Under Construction
# ..        ...     ...        ...            ...                 ...
# 775         2       1  1455 sqft   ₹ 6,116/sqft       Ready to Move
# 776         1     NaN   530 sqft  ₹ 45,283/sqft       Ready to Move
# 777         2     NaN  1100 sqft   ₹ 8,636/sqft       Ready to Move
# 778         4       2  3530 sqft   ₹ 7,790/sqft       Ready to Move
# 779         4       1  2400 sqft   ₹ 6,667/sqft       Ready to Move
#
#     Transaction Type  ...           Lifts  \
# 0       New Property  ...
# 1            Apr '22  ...             Nan
# 2       New Property  ...             Nan
# 3            Dec '24  ...               2
# 4            Aug '20  ...             Nan
# ..               ...  ...             ...
# 775           Resale  ...             Nan
# 776           Resale  ...  Semi-Furnished
# 777           Resale  ...             Nan
# 778           Resale  ...             Nan
# 779           Resale  ...             Nan
#
#                                            Description  \
# 0    Luxury Villas Plots in Gated Community for sal...
# 1    Hill Crest is a luxurious and affordable resid...
# 2    A Home Where Everything is a Blessing. A premi...
# 3    Sun & Sanctum is a tall stepped architectural ...
# 4    Sri Nandana Royal is developed by Sri Nandana ...
# ..                                                 ...
# 775  Ushodaya Aqua of Ushodaya Developers is one am...
# 776  Well-positioned in the proximity of prominent ...
# 777
# 778  An appealingly designed 4BHK penthouse is avai...
# 779  4 BHK Vila is available for sale with Good Ame...
#
#                                          Price breakup  \
# 0                                           ₹ 19.2 Lac
# 1                           ₹ 45.0 Lac ₹ 2,000 Monthly
# 2                            ₹ 1.54 Cr ₹ 2,000 Monthly
# 3                            ₹ 1.06 Cr ₹ 3,000 Monthly
# 4                           ₹ 46.5 Lac ₹ 30,000 Yearly
# ..                                                 ...
# 775  ₹ 89.0 Lac ₹ 4,98,399 Approx. Registration Cha...
# 776                                          ₹ 2.40 Cr
# 777                                         ₹ 95.0 Lac
# 778                                          ₹ 2.75 Cr
# 779  ₹ 1.60 Cr ₹ 8,95,999 Approx. Registration Char...
#
#                                              Landmarks Age of construction  \
# 0                            Celebrity Prime Eco Front                 NaN
# 1                                   Vitrified, Granite                 NaN
# 2                                    Vitrified, Marble                 NaN
# 3                                   24 Hours Available                 NaN
# 4                                            Vitrified                 NaN
# ..                                                 ...                 ...
# 775  TSIB - 1 KM\nSupermarket - 500 mtr\nUniversity...                 NaN
# 776                                   New Construction                 NaN
# 777                                                                    NaN
# 778                                  Garden/Park, Pool                 NaN
# 779                    Near Jigani Bomsandra link Road                 NaN
#
#     Price comparison Expected rent Monthly EMI               Owner/Builder  \
# 0                NaN           NaN         NaN                         Nan
# 1                NaN           NaN         NaN  Sairam Dwellings Pvt. Ltd.
# 2                NaN           NaN         NaN              Amsha Ventures
# 3                NaN           NaN         NaN       Assetz Property Group
# 4                NaN           NaN         NaN        Sri Nandana Builders
# ..               ...           ...         ...                         ...
# 775              NaN           NaN         NaN           Ushodaya Builders
# 776              NaN           NaN         NaN                         Nan
# 777              NaN           NaN         NaN                         Nan
# 778              NaN           NaN         NaN                         Nan
# 779              NaN           NaN         NaN           Celibrity Housing
#
#             Type of Ownership
# 0                    Freehold
# 1    Sai Gangothri Hill Crest
# 2              Bhuvi By Amsha
# 3             Sun and Sanctum
# 4           Sri Nandana Royal
# ..                        ...
# 775             Ushodaya Aqua
# 776                       NaN
# 777                       NaN
# 778                       NaN
# 779         Celebrity Harmony
#
# [780 rows x 23 columns]
